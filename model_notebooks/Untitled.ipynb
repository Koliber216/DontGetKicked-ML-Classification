# %%
import matplotlib.pyplot as plt

# %%
plt.bar(['without oversampling','with oversampling'],[90,78.38])
plt.title('Comparing accuracy with Oversamping and without oversampling on Xgboost')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
