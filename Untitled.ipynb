# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
plt.bar(x= ['With oversampling','Without Oversampling'], height = [68.35,87.69])
plt.title('Comparing accuracy of XGBoost', fontsize = 16)
plt.show()

# %%
# ?plt.bar
